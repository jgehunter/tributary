# %% [markdown]
# # Data Exploration
#
# Understand what data we have, its quality, and basic characteristics.
#
# **Unit of analysis**: The orderbook (each token_id represents one orderbook)
#
# **Key questions**:
# 1. What data do we have? (inventory)
# 2. What is the data quality? (completeness, gaps)
# 3. What are the characteristics of each orderbook?

# %%
import pandas as pd
import numpy as np
import json
from datetime import datetime, timedelta
from sqlalchemy import create_engine
import plotly.express as px
import plotly.graph_objects as go

pd.set_option('display.max_colwidth', 100)
pd.set_option('display.max_rows', 50)

engine = create_engine('postgresql://admin:quest@localhost:8812/qdb')

# %% [markdown]
# ## 1. Data Inventory
#
# What tables do we have and what's in them?

# %%
# Table-level statistics
inventory = []

for table, ts_col in [('trades', 'timestamp'), ('orderbook_snapshots', 'timestamp'), ('markets', 'creation_time')]:
    try:
        q = f"SELECT count() as n, min({ts_col}) as first_ts, max({ts_col}) as last_ts FROM {table}"
        row = pd.read_sql(q, engine).iloc[0]
        inventory.append({
            'table': table,
            'records': int(row['n']),
            'first': row['first_ts'],
            'last': row['last_ts']
        })
    except Exception as e:
        inventory.append({'table': table, 'records': 0, 'first': None, 'last': None})

df_inventory = pd.DataFrame(inventory)
df_inventory['duration'] = (df_inventory['last'] - df_inventory['first']).apply(
    lambda x: f"{x.days}d {x.seconds//3600}h" if pd.notna(x) else None
)
display(df_inventory)
# Out:
#                  table  records                      first  \
# 0               trades    29165 2025-02-05 23:41:11.000000
# 1  orderbook_snapshots    38379 2026-01-19 07:12:35.433000
# 2              markets       14 2025-01-05 01:34:48.860057
#
#                         last  duration
# 0 2026-01-19 11:11:54.000000  347d 11h
# 1 2026-01-19 11:12:21.376000     0d 3h
# 2 2026-01-04 18:56:17.032325  364d 17h

# %%
# Count unique orderbooks (token_ids)
n_orderbooks = pd.read_sql("SELECT count(distinct token_id) as n FROM orderbook_snapshots", engine).iloc[0]['n']
n_markets = pd.read_sql("SELECT count(distinct market_id) as n FROM markets", engine).iloc[0]['n']

print(f"Unique orderbooks (token_ids): {n_orderbooks}")
print(f"Unique markets: {n_markets}")
print(f"Expected orderbooks per market: ~2 (Yes/No tokens)")
# Out:
# Unique orderbooks (token_ids): 28
# Unique markets: 14
# Expected orderbooks per market: ~2 (Yes/No tokens)

# %% [markdown]
# ## 2. Orderbook Catalog
#
# **Master reference**: Every orderbook with its market context and current state.
#
# This is the foundation for all analysis - we need to know what each token_id represents.

# %%
# Build token_id -> (market_slug, outcome_name) mapping from markets metadata
markets_df = pd.read_sql("SELECT market_id, market_slug, question, metadata FROM markets", engine)

token_info = {}
for _, row in markets_df.iterrows():
    try:
        meta = json.loads(row['metadata']) if isinstance(row['metadata'], str) else row['metadata']
        outcomes = meta.get('outcomes', ['Yes', 'No'])
        token_ids = meta.get('clob_token_ids', [])
        
        for i, tid in enumerate(token_ids):
            token_info[tid] = {
                'market_id': row['market_id'],
                'market_slug': row['market_slug'],
                'question': row['question'][:80],
                'outcome': outcomes[i] if i < len(outcomes) else f'Outcome_{i}'
            }
    except:
        continue

print(f"Token mappings built: {len(token_info)}")
# Out:
# Token mappings built: 28

# %%
# Get latest snapshot for each orderbook to see current state
latest_query = """
SELECT 
    token_id,
    market_id,
    last(mid_price) as last_price,
    last(spread_bps) as last_spread_bps,
    last(total_bid_volume) as last_bid_vol,
    last(total_ask_volume) as last_ask_vol,
    count() as n_snapshots,
    max(timestamp) as last_seen
FROM orderbook_snapshots
"""

df_orderbooks = pd.read_sql(latest_query, engine)

# Enrich with market context
df_orderbooks['outcome'] = df_orderbooks['token_id'].map(lambda x: token_info.get(x, {}).get('outcome', 'Unknown'))
df_orderbooks['question'] = df_orderbooks['token_id'].map(lambda x: token_info.get(x, {}).get('question', 'Unknown'))

# Classify by price regime
def price_regime(p):
    if p < 0.10: return 'Low (<10%)'
    elif p > 0.90: return 'High (>90%)'
    else: return 'Mid (10-90%)'

df_orderbooks['price_regime'] = df_orderbooks['last_price'].apply(price_regime)

# Sort by last price descending
df_orderbooks = df_orderbooks.sort_values('last_price', ascending=False)

print(f"\nOrderbook Catalog ({len(df_orderbooks)} orderbooks):")
display(df_orderbooks[['question', 'outcome', 'last_price', 'last_spread_bps', 'price_regime', 'n_snapshots']].head(30))
# Out:
# Orderbook Catalog (28 orderbooks):
#                                                                  question  \
# 16    Fed increases interest rates by 25+ bps after January 2026 meeting?
# 1                     Will Slavia Pragu win the 2025–26 Champions League?
# 10                     Will Leeds win the 2025–26 English Premier League?
# 14    Fed decreases interest rates by 50+ bps after January 2026 meeting?
# 22  Will Chelsea Clinton win the 2028 Democratic presidential nomination?
# 3                        Will Elon cut the budget by at least 5% in 2025?
# 24          Will MrBeast win the 2028 Democratic presidential nomination?
# 27    Will Oprah Winfrey win the 2028 Democratic presidential nomination?
# 26      Will Andrew Yang win the 2028 Democratic presidential nomination?
# 5     Will Elon and DOGE cut more than $250b in federal spending in 2025?
# 7                       Will Trump deport 750,000 or more people in 2025?
# 20     Fed decreases interest rates by 25 bps after January 2026 meeting?
# 17            No change in Fed interest rates after January 2026 meeting?
# 12                  Khamenei out as Supreme Leader of Iran by January 31?
# 11                  Khamenei out as Supreme Leader of Iran by January 31?
# 18            No change in Fed interest rates after January 2026 meeting?
# 19     Fed decreases interest rates by 25 bps after January 2026 meeting?
# 6                       Will Trump deport 750,000 or more people in 2025?
# 4     Will Elon and DOGE cut more than $250b in federal spending in 2025?
# 8     Will Oprah Winfrey win the 2028 Democratic presidential nomination?
# 25      Will Andrew Yang win the 2028 Democratic presidential nomination?
# 23          Will MrBeast win the 2028 Democratic presidential nomination?
# 2                        Will Elon cut the budget by at least 5% in 2025?
# 21  Will Chelsea Clinton win the 2028 Democratic presidential nomination?
# 13    Fed decreases interest rates by 50+ bps after January 2026 meeting?
# 0                     Will Slavia Pragu win the 2025–26 Champions League?
# 9                      Will Leeds win the 2025–26 English Premier League?
# 15    Fed increases interest rates by 25+ bps after January 2026 meeting?
#
#    outcome  last_price  last_spread_bps price_regime  n_snapshots
# 16      No      0.9995        10.005003  High (>90%)         1372
# 1       No      0.9985        10.015023  High (>90%)         1371
# 10      No      0.9985        10.015023  High (>90%)         1372
# 14      No      0.9975        10.025063  High (>90%)         1372
# 22      No      0.9965        10.035123  High (>90%)         1371
# 3       No      0.9960        20.080321  High (>90%)         1372
# 24      No      0.9955        10.045203  High (>90%)         1371
# 27      No      0.9945        10.055304  High (>90%)         1371
# 26      No      0.9945        10.055304  High (>90%)         1371
# 5       No      0.9880        40.485830  High (>90%)         1372
# 7       No      0.9775       153.452685  High (>90%)         1372
# 20      No      0.9645        10.368066  High (>90%)         1372
# 17     Yes      0.9615        10.400416  High (>90%)         1372
# 12      No      0.9350       106.951872  High (>90%)         1372
# 11     Yes      0.0650      1538.461538   Low (<10%)         1372
# 18      No      0.0385       259.740260   Low (<10%)         1372
# 19     Yes      0.0355       281.690141   Low (<10%)         1372
# 6      Yes      0.0225      6666.666667   Low (<10%)         1372
# 4      Yes      0.0120      3333.333333   Low (<10%)         1372
# 8      Yes      0.0055      1818.181818   Low (<10%)         1372
# 25     Yes      0.0055      1818.181818   Low (<10%)         1371
# 23     Yes      0.0045      2222.222222   Low (<10%)         1371
# 2      Yes      0.0040      5000.000000   Low (<10%)         1372
# 21     Yes      0.0035      2857.142857   Low (<10%)         1371
# 13     Yes      0.0025      4000.000000   Low (<10%)         1372
# 0      Yes      0.0015      6666.666667   Low (<10%)         1371
# 9      Yes      0.0015      6666.666667   Low (<10%)         1372
# 15     Yes      0.0005     20000.000000   Low (<10%)         1372

# %%
# Price regime distribution
regime_counts = df_orderbooks['price_regime'].value_counts()
print("\nPrice Regime Distribution:")
for regime, count in regime_counts.items():
    pct = count / len(df_orderbooks) * 100
    print(f"  {regime}: {count} orderbooks ({pct:.0f}%)")

# Visual
fig = px.pie(values=regime_counts.values, names=regime_counts.index, 
             title='Orderbooks by Price Regime',
             color_discrete_sequence=['#ff6b6b', '#4ecdc4', '#45b7d1'])
fig.update_layout(height=350)
fig.show()
# Out:
# Price Regime Distribution:
#   High (>90%): 14 orderbooks (50%)
#   Low (<10%): 14 orderbooks (50%)

# %% [markdown]
# ## 3. Data Quality
#
# How complete is our data? Are there gaps?

# %%
# Snapshot frequency per orderbook
freq_query = """
SELECT 
    token_id,
    count() as n_snapshots,
    min(timestamp) as first_snapshot,
    max(timestamp) as last_snapshot
FROM orderbook_snapshots
WHERE timestamp > dateadd('d', -3, now())
"""

df_freq = pd.read_sql(freq_query, engine)
df_freq['hours_covered'] = (df_freq['last_snapshot'] - df_freq['first_snapshot']).dt.total_seconds() / 3600
df_freq['snapshots_per_hour'] = df_freq['n_snapshots'] / df_freq['hours_covered'].replace(0, np.nan)
df_freq['outcome'] = df_freq['token_id'].map(lambda x: token_info.get(x, {}).get('outcome', '?'))
df_freq['question'] = df_freq['token_id'].map(lambda x: token_info.get(x, {}).get('question', '?')[:50])

print("Snapshot frequency (last 3 days):")
display(df_freq[['question', 'outcome', 'n_snapshots', 'snapshots_per_hour']].sort_values('snapshots_per_hour', ascending=False))
# Out:
# Snapshot frequency (last 3 days):
#                                               question outcome  n_snapshots  \
# 14  Will Oprah Winfrey win the 2028 Democratic preside      No         1373
# 2     Will Elon cut the budget by at least 5% in 2025?      No         1374
# 22    Will Elon cut the budget by at least 5% in 2025?     Yes         1374
# 1   Will MrBeast win the 2028 Democratic presidential       No         1373
# 23  Will MrBeast win the 2028 Democratic presidential      Yes         1373
# 19  Will Andrew Yang win the 2028 Democratic president     Yes         1373
# 25  Will Andrew Yang win the 2028 Democratic president      No         1373
# 8   Will Oprah Winfrey win the 2028 Democratic preside     Yes         1374
# 16  Will Chelsea Clinton win the 2028 Democratic presi      No         1373
# 11  Will Chelsea Clinton win the 2028 Democratic presi     Yes         1373
# 17  Will Leeds win the 2025–26 English Premier League?     Yes         1374
# 26  Will Leeds win the 2025–26 English Premier League?      No         1374
# 24  No change in Fed interest rates after January 2026      No         1374
# 18  No change in Fed interest rates after January 2026     Yes         1374
# 27  Fed decreases interest rates by 50+ bps after Janu     Yes         1374
# 5   Fed decreases interest rates by 50+ bps after Janu      No         1374
# 20  Fed increases interest rates by 25+ bps after Janu      No         1374
# 12  Fed increases interest rates by 25+ bps after Janu     Yes         1374
# 0   Fed decreases interest rates by 25 bps after Janua     Yes         1374
# 9   Fed decreases interest rates by 25 bps after Janua      No         1374
# 3   Khamenei out as Supreme Leader of Iran by January       No         1374
# 7   Khamenei out as Supreme Leader of Iran by January      Yes         1374
# 10   Will Trump deport 750,000 or more people in 2025?     Yes         1374
# 15   Will Trump deport 750,000 or more people in 2025?      No         1374
# 13  Will Elon and DOGE cut more than $250b in federal      Yes         1374
# 21  Will Elon and DOGE cut more than $250b in federal       No         1374
# 4   Will Slavia Pragu win the 2025–26 Champions League      No         1373
# 6   Will Slavia Pragu win the 2025–26 Champions League     Yes         1373
#
#     snapshots_per_hour
# 14          364.277434
# 2           362.789944
# 22          362.789944
# 1           362.028573
# 23          362.028573
# 19          361.294661
# 25          361.294661
# 8           360.662711
# 16          358.248003
# 11          358.248003
# 17          357.424540
# 26          357.424540
# 24          357.299347
# 18          357.299347
# 27          357.296534
# 5           357.296534
# 20          357.296508
# 12          357.296508
# 0           357.026056
# 9           357.026056
# 3           356.925299
# 7           356.925299
# 10          355.205654
# 15          355.205654
# 13          354.608734
# 21          354.608734
# 4           343.585401
# 6           343.585401

# %%
# Check for data gaps - count snapshots per hour
gaps_query = """
SELECT 
    timestamp,
    count() as n_snapshots
FROM orderbook_snapshots
WHERE timestamp > dateadd('d', -3, now())
SAMPLE BY 1h
ALIGN TO CALENDAR
"""

df_gaps = pd.read_sql(gaps_query, engine)

# Identify low-data hours
median_per_hour = df_gaps['n_snapshots'].median()
low_data_hours = df_gaps[df_gaps['n_snapshots'] < median_per_hour * 0.5]

print(f"Median snapshots per hour: {median_per_hour:.0f}")
print(f"Hours with <50% of median: {len(low_data_hours)}")

# Visualize
fig = go.Figure()
fig.add_trace(go.Bar(x=df_gaps['timestamp'], y=df_gaps['n_snapshots'], name='Snapshots'))
fig.add_hline(y=median_per_hour, line_dash='dash', line_color='red', 
              annotation_text=f'Median: {median_per_hour:.0f}')
fig.update_layout(title='Data Collection Completeness (snapshots/hour)', height=350,
                  xaxis_title='Time', yaxis_title='Snapshots')
fig.show()
# Out:
# Median snapshots per hour: 9952
# Hours with <50% of median: 1

# %% [markdown]
# ## 4. Trading Activity
#
# Which orderbooks have actual trading activity?

# %%
# Trades per orderbook
trades_query = """
SELECT 
    token_id,
    market_id,
    count() as n_trades,
    sum(value) as total_volume,
    avg(size) as avg_trade_size
FROM trades
WHERE timestamp > dateadd('d', -7, now())
"""

df_trades = pd.read_sql(trades_query, engine)
df_trades['outcome'] = df_trades['token_id'].map(lambda x: token_info.get(x, {}).get('outcome', '?'))
df_trades['question'] = df_trades['token_id'].map(lambda x: token_info.get(x, {}).get('question', '?')[:50])

# Sort by volume
df_trades = df_trades.sort_values('total_volume', ascending=False)

print(f"\nTrading Activity by Orderbook (last 7 days):")
display(df_trades[['question', 'outcome', 'n_trades', 'total_volume', 'avg_trade_size']].head(20))
# Out:
# Trading Activity by Orderbook (last 7 days):
#                                               question outcome  n_trades  \
# 18  Fed increases interest rates by 25+ bps after Janu      No      1803
# 24  Fed decreases interest rates by 50+ bps after Janu      No      1866
# 27  No change in Fed interest rates after January 2026     Yes      2053
# 3   Will Chelsea Clinton win the 2028 Democratic presi      No      1436
# 12  Will Oprah Winfrey win the 2028 Democratic preside      No      1269
# 16  Will Leeds win the 2025–26 English Premier League?      No      1864
# 0   Will MrBeast win the 2028 Democratic presidential       No      1020
# 22  Khamenei out as Supreme Leader of Iran by January       No      1032
# 5   Will Andrew Yang win the 2028 Democratic president      No       891
# 20  Fed decreases interest rates by 25 bps after Janua      No      1358
# 2   Will Slavia Pragu win the 2025–26 Champions League      No       923
# 23  Khamenei out as Supreme Leader of Iran by January      Yes      1312
# 21  Fed decreases interest rates by 25 bps after Janua     Yes      1013
# 25  Fed decreases interest rates by 50+ bps after Janu     Yes       410
# 11  Will Oprah Winfrey win the 2028 Democratic preside     Yes       769
# 26  No change in Fed interest rates after January 2026      No       448
# 6   Will Andrew Yang win the 2028 Democratic president     Yes      1020
# 4   Will MrBeast win the 2028 Democratic presidential      Yes       438
# 1   Will Chelsea Clinton win the 2028 Democratic presi     Yes       417
# 19  Fed increases interest rates by 25+ bps after Janu     Yes       385
#
#     total_volume  avg_trade_size
# 18  5.127792e+06     2848.082613
# 24  4.947141e+06     2659.288388
# 27  1.379746e+06      699.684239
# 3   1.359076e+06      949.764271
# 12  1.001536e+06      792.667204
# 16  6.122445e+05      328.939440
# 0   5.340715e+05      525.959201
# 22  3.638410e+05      380.563464
# 5   3.490017e+05      393.857701
# 20  3.215258e+05      245.316234
# 2   2.885251e+05      313.064202
# 23  7.846941e+04      820.189363
# 21  5.498761e+04     1494.330107
# 25  2.100249e+04    16191.392073
# 11  1.821511e+04     5636.346909
# 26  1.556418e+04      890.111900
# 6   1.017249e+04     1837.413327
# 4   5.741327e+03     2803.826027
# 1   4.559435e+03     3265.622398
# 19  3.691530e+03     6546.347455

# %%
# Activity distribution
active_orderbooks = len(df_trades[df_trades['n_trades'] > 0])
high_activity = len(df_trades[df_trades['n_trades'] >= 100])

print(f"\nActivity Summary:")
print(f"  Orderbooks with any trades: {active_orderbooks}")
print(f"  Orderbooks with 100+ trades: {high_activity}")
print(f"  Total volume (7d): ${df_trades['total_volume'].sum():,.0f}")
# Out:
# Activity Summary:
#   Orderbooks with any trades: 28
#   Orderbooks with 100+ trades: 24
#   Total volume (7d): $16,501,979

# %%
# Trade size distribution
size_query = """
SELECT size, value FROM trades 
WHERE timestamp > dateadd('d', -7, now())
LIMIT 10000
"""
df_sizes = pd.read_sql(size_query, engine)

if len(df_sizes) > 0:
    print(f"\nTrade Size Distribution (n={len(df_sizes)}):")
    print(df_sizes['value'].describe().round(2))
    
    fig = px.histogram(df_sizes, x='value', nbins=50, title='Trade Value Distribution',
                       labels={'value': 'Trade Value (USD)'})
    fig.update_layout(height=350)
    fig.update_yaxes(type='log')
    fig.show()
# Out:
# Trade Size Distribution (n=10000):
# count    10000.00
# mean       475.59
# std       1607.41
# min          0.00
# 25%          6.00
# 50%         51.42
# 75%        334.19
# max      36317.30
# Name: value, dtype: float64

# %% [markdown]
# ## 5. Summary
#
# Key findings about our dataset.

# %%
# Create summary dataframe combining orderbook info with trading activity
df_summary = df_orderbooks[['token_id', 'question', 'outcome', 'last_price', 'last_spread_bps', 'price_regime', 'n_snapshots']].copy()

# Merge with trading data
trade_cols = df_trades[['token_id', 'n_trades', 'total_volume']].copy()
df_summary = df_summary.merge(trade_cols, on='token_id', how='left')
df_summary['n_trades'] = df_summary['n_trades'].fillna(0).astype(int)
df_summary['total_volume'] = df_summary['total_volume'].fillna(0)

# Classify activity level
def activity_level(n):
    if n == 0: return 'Inactive'
    elif n < 50: return 'Low'
    elif n < 500: return 'Medium'
    else: return 'High'

df_summary['activity'] = df_summary['n_trades'].apply(activity_level)

print("\nComplete Orderbook Summary:")
display(df_summary.sort_values('total_volume', ascending=False))
# Out:
# Complete Orderbook Summary:
#                                                                           token_id  \
# 0    42139849929574046088630785796780813725435914859433767469767950066058132350666
# 3    71478852790279095447182996049071040792010759617668969799049179229104800573786
# 12  112838095111461683880944516726938163688341306245473734071798778736646352193304
# 4    76057920052421891902791411567177996435483774677774664174053982044923692373687
# 7    44046525152074436753629616217525652949736205933417533647338274649282385796755
# 2    79742853692640441630014447218057231927327132180925275737649345065452061252209
# 6    93910251767329056141706007839545721784238465183449597462421810827705938093892
# 13   62595435619678438799673612599999067112702849851098967060818869994133628780778
# 8    21234886083000978203440582985665409733123024063268807484684316771005736994028
# 11   48193521645113703700467246669338225849301704920590102230072263970163239985027
# 1    34146754045968539016734059757762644473418677163720213182630410899169414081030
# 14  101434403359553929764780234916919166959889590658679054429843672204390513588056
# 16   92703761682322480664976766247614127878023988651992837287050266308961660624165
# 24   11862165566757345985240476164489718219056735011698825377388402888080786399275
# 19    2213957649161627793381994368131485505647723208738124952452819345058597751695
# 15    7321318078891059430231591636389479745928915782241484131001985601124919020061
# 20  102504892414163237174864879683522880588750452841477290216845150938663289742135
# 21   51035537065442638321333063915918274102446051033989435618245745345113522914516
# 23   46211769122513729244602558513001215391004042100934296321661285791281233261657
# 27   16419649354067298412736919830777830730026677464626899811394461690794060330642
# 9    79516121807256184736227920754945730465880754940725759201193439378549308939672
# 10   59259495934562596318644973716893809974860301509869285036503555129962149752635
# 25  101564510739658892373078552770639793245135038809362064410922020660639564617759
# 5    20002636398944597965698652220992177552927816915094913583821579024925426590022
# 22   96361925776989336186111887920533578209326565663637092688733016597062311745569
# 17   97449340182256366014320155718265676486703217567849039806162053075113517266910
# 26   76060545169704703774306339799160632690199220587187333652682231353030966296372
# 18   70512916946285526357165287373537570327431985324385225788636160168740471920430
#
#                                                                  question  \
# 0     Fed increases interest rates by 25+ bps after January 2026 meeting?
# 3     Fed decreases interest rates by 50+ bps after January 2026 meeting?
# 12            No change in Fed interest rates after January 2026 meeting?
# 4   Will Chelsea Clinton win the 2028 Democratic presidential nomination?
# 7     Will Oprah Winfrey win the 2028 Democratic presidential nomination?
# 2                      Will Leeds win the 2025–26 English Premier League?
# 6           Will MrBeast win the 2028 Democratic presidential nomination?
# 13                  Khamenei out as Supreme Leader of Iran by January 31?
# 8       Will Andrew Yang win the 2028 Democratic presidential nomination?
# 11     Fed decreases interest rates by 25 bps after January 2026 meeting?
# 1                     Will Slavia Pragu win the 2025–26 Champions League?
# 14                  Khamenei out as Supreme Leader of Iran by January 31?
# 16     Fed decreases interest rates by 25 bps after January 2026 meeting?
# 24    Fed decreases interest rates by 50+ bps after January 2026 meeting?
# 19    Will Oprah Winfrey win the 2028 Democratic presidential nomination?
# 15            No change in Fed interest rates after January 2026 meeting?
# 20      Will Andrew Yang win the 2028 Democratic presidential nomination?
# 21          Will MrBeast win the 2028 Democratic presidential nomination?
# 23  Will Chelsea Clinton win the 2028 Democratic presidential nomination?
# 27    Fed increases interest rates by 25+ bps after January 2026 meeting?
# 9     Will Elon and DOGE cut more than $250b in federal spending in 2025?
# 10                      Will Trump deport 750,000 or more people in 2025?
# 25                    Will Slavia Pragu win the 2025–26 Champions League?
# 5                        Will Elon cut the budget by at least 5% in 2025?
# 22                       Will Elon cut the budget by at least 5% in 2025?
# 17                      Will Trump deport 750,000 or more people in 2025?
# 26                     Will Leeds win the 2025–26 English Premier League?
# 18    Will Elon and DOGE cut more than $250b in federal spending in 2025?
#
#    outcome  last_price  last_spread_bps price_regime  n_snapshots  n_trades  \
# 0       No      0.9995        10.005003  High (>90%)         1372      1803
# 3       No      0.9975        10.025063  High (>90%)         1372      1866
# 12     Yes      0.9615        10.400416  High (>90%)         1372      2053
# 4       No      0.9965        10.035123  High (>90%)         1371      1436
# 7       No      0.9945        10.055304  High (>90%)         1371      1269
# 2       No      0.9985        10.015023  High (>90%)         1372      1864
# 6       No      0.9955        10.045203  High (>90%)         1371      1020
# 13      No      0.9350       106.951872  High (>90%)         1372      1032
# 8       No      0.9945        10.055304  High (>90%)         1371       891
# 11      No      0.9645        10.368066  High (>90%)         1372      1358
# 1       No      0.9985        10.015023  High (>90%)         1371       923
# 14     Yes      0.0650      1538.461538   Low (<10%)         1372      1312
# 16     Yes      0.0355       281.690141   Low (<10%)         1372      1013
# 24     Yes      0.0025      4000.000000   Low (<10%)         1372       410
# 19     Yes      0.0055      1818.181818   Low (<10%)         1372       769
# 15      No      0.0385       259.740260   Low (<10%)         1372       448
# 20     Yes      0.0055      1818.181818   Low (<10%)         1371      1020
# 21     Yes      0.0045      2222.222222   Low (<10%)         1371       438
# 23     Yes      0.0035      2857.142857   Low (<10%)         1371       417
# 27     Yes      0.0005     20000.000000   Low (<10%)         1372       385
# 9       No      0.9880        40.485830  High (>90%)         1372       204
# 10      No      0.9775       153.452685  High (>90%)         1372        66
# 25     Yes      0.0015      6666.666667   Low (<10%)         1371       120
# 5       No      0.9960        20.080321  High (>90%)         1372        46
# 22     Yes      0.0040      5000.000000   Low (<10%)         1372        96
# 17     Yes      0.0225      6666.666667   Low (<10%)         1372        69
# 26     Yes      0.0015      6666.666667   Low (<10%)         1372       164
# 18     Yes      0.0120      3333.333333   Low (<10%)         1372       178
#
#     total_volume activity
# 0   5.127792e+06     High
# 3   4.947141e+06     High
# 12  1.379746e+06     High
# 4   1.359076e+06     High
# 7   1.001536e+06     High
# 2   6.122445e+05     High
# 6   5.340715e+05     High
# 13  3.638410e+05     High
# 8   3.490017e+05     High
# 11  3.215258e+05     High
# 1   2.885251e+05     High
# 14  7.846941e+04     High
# 16  5.498761e+04     High
# 24  2.100249e+04   Medium
# 19  1.821511e+04     High
# 15  1.556418e+04   Medium
# 20  1.017249e+04     High
# 21  5.741327e+03   Medium
# 23  4.559435e+03   Medium
# 27  3.691530e+03   Medium
# 9   2.596681e+03   Medium
# 10  1.048113e+03   Medium
# 25  4.087489e+02   Medium
# 5   3.908239e+02      Low
# 22  3.512920e+02   Medium
# 17  1.331931e+02   Medium
# 26  1.082025e+02   Medium
# 18  3.708154e+01   Medium

# %%
# Export for use in other notebooks
df_summary.to_csv('orderbook_summary.csv', index=False)
print("Saved orderbook_summary.csv for use in liquidity analysis")

# %%
engine.dispose()
print("Done.")
# Out:
# Done.
